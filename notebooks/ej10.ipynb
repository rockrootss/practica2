# %%
import sys
import os

#Obtener la ruta absoluta del directorio raiz del proyecto 
sys.path.append(os.path.abspath("../src"))

from funciones import *

rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

# Diccionario para almacenar las estadísticas totales
stats = {} # kills, assists, deaths y puntos totales de cada jugador
mvp_count = {} # Cuenta cuantas veces un jugador fue MVP

round_count = 1                   #cuento las rondas

#Itero entre las rondas
for round in rounds:
    
    round_scores = {}    # Diccionario para almacenar los puntos de cada jugador en la ronda

    #Itero entre los jugadores de esa ronda
    for player, data in round.items(): 
        kills = data['kills']    
        assists = data['assists']
        deaths =  data['deaths']
        points = (kills * 3) + (assists * 1) - (1 if deaths else 0)  #sumo los puntos de cada jugador

        #Si el jugador no existe en stats, lo agrego con todo en 0
        if player not in stats:                                                    
            stats[player] = {'kills': 0, 'assists': 0, 'deaths': 0, 'points': 0}
            mvp_count[player] = 0
        
        #Actualizo estadisticas de jugador
        stats[player]['kills'] += kills
        stats[player]['assists'] += assists
        stats[player]['deaths'] += 1 if deaths else 0
        stats[player]['points'] += points

        # Guardar la puntuación de la ronda para determinar MVP
        round_scores[player] = points

    # Determinar el MVP de la ronda
    mvp_player = determinar_mvp(round_scores, mvp_count)

    # Ordenar por puntos totales. Mostrar ranking de la ronda y MVP
    mostrar_ranking(round_count,stats,mvp_player)
    
    round_count += 1  # Incrementar número de ronda

# Generar el ranking final
generar_ranking_final(stats, mvp_count)
# Out:
# Ranking Ronda 1:
# Shadow: 2 Kills, 1 Assists, 1 Muertes, 6 Puntos
# Viper: 1 Kills, 2 Assists, 1 Muertes, 4 Puntos
# Reaper: 1 Kills, 1 Assists, 0 Muertes, 4 Puntos
# Blaze: 1 Kills, 0 Assists, 0 Muertes, 3 Puntos
# Frost: 0 Kills, 1 Assists, 0 Muertes, 1 Puntos
# --------------------------------
# MVP: Shadow
# --------------------------------
# Ranking Ronda 2:
# Shadow: 2 Kills, 3 Assists, 1 Muertes, 8 Puntos
# Blaze: 3 Kills, 0 Assists, 1 Muertes, 8 Puntos
# Viper: 2 Kills, 3 Assists, 1 Muertes, 8 Puntos
# Frost: 2 Kills, 2 Assists, 1 Muertes, 7 Puntos
# Reaper: 1 Kills, 2 Assists, 0 Muertes, 5 Puntos
# --------------------------------
# MVP: Frost
# --------------------------------
# Ranking Ronda 3:
# Blaze: 5 Kills, 2 Assists, 2 Muertes, 15 Puntos
# Shadow: 3 Kills, 3 Assists, 1 Muertes, 11 Puntos
# Viper: 3 Kills, 4 Assists, 2 Muertes, 11 Puntos
# Reaper: 2 Kills, 3 Assists, 0 Muertes, 9 Puntos
# Frost: 2 Kills, 3 Assists, 1 Muertes, 8 Puntos
# --------------------------------
# MVP: Blaze
# --------------------------------
# Ranking Ronda 4:
# Shadow: 5 Kills, 4 Assists, 1 Muertes, 18 Puntos
# Blaze: 6 Kills, 2 Assists, 3 Muertes, 17 Puntos
# Viper: 3 Kills, 6 Assists, 2 Muertes, 13 Puntos
# Reaper: 3 Kills, 4 Assists, 0 Muertes, 13 Puntos
# Frost: 3 Kills, 4 Assists, 2 Muertes, 11 Puntos
# --------------------------------
# MVP: Shadow
# --------------------------------
# Ranking Ronda 5:
# Shadow: 6 Kills, 6 Assists, 2 Muertes, 22 Puntos
# Blaze: 6 Kills, 3 Assists, 3 Muertes, 18 Puntos
# Viper: 5 Kills, 6 Assists, 3 Muertes, 18 Puntos
# Reaper: 4 Kills, 5 Assists, 1 Muertes, 16 Puntos
# Frost: 4 Kills, 5 Assists, 2 Muertes, 15 Puntos
# --------------------------------
# MVP: Viper
# --------------------------------
# Ranking Final:
# Jugador: Shadow , Kills:6 , Assists:6 , Deaths:2 , MVP: 2 , Puntos:22
# Jugador: Blaze , Kills:6 , Assists:3 , Deaths:3 , MVP: 1 , Puntos:18
# Jugador: Viper , Kills:5 , Assists:6 , Deaths:3 , MVP: 1 , Puntos:18
# Jugador: Reaper , Kills:4 , Assists:5 , Deaths:1 , MVP: 0 , Puntos:16
# Jugador: Frost , Kills:4 , Assists:5 , Deaths:2 , MVP: 1 , Puntos:15
